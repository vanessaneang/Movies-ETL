# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection   budget  \
# 6654   False                   NaN  3800000
# 20804  False                   NaN        0
# 6856   False                   NaN  1250000
# 25182  False                   NaN        0
# 43187  False                   NaN        0
#
#                                                   genres  \
# 6654   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 20804                     [{'id': 35, 'name': 'Comedy'}]
# 6856   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 25182                                                 []
# 43187  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#
#                                    homepage      id    imdb_id  \
# 6654                                    NaN   29161  tt0087909
# 20804                                   NaN   31664  tt0040582
# 6856                                    NaN    1643  tt0070849
# 25182                                   NaN   49467  tt0174719
# 43187  https://www.facebook.com/AtaudBlanco  399615  tt5767182
#
#       original_language                    original_title  \
# 6654                 en                         Phenomena
# 20804                en                   Mexican Hayride
# 6856                 fr             Ultimo tango a Parigi
# 25182                pl                            Hamles
# 43187                es  Ataúd blanco: El juego diabólico
#
#                                                 overview  ... release_date  \
# 6654   A young girl, with an amazing ability to commu...  ...   1985-01-31
# 20804  Two con men selling phony stock flee to Mexico...  ...   1948-12-01
# 6856   A young Parisian woman begins a sordid affair ...  ...   1972-10-14
# 25182  In Little Hamlet, Skolimowski shows his predil...  ...   1960-01-01
# 43187  Virginia will do the impossible in order to re...  ...   2016-07-21
#
#           revenue runtime                                   spoken_languages  \
# 6654          0.0   116.0  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...
# 20804         0.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6856   36144000.0   129.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 25182         0.0     8.0            [{'iso_639_1': 'pl', 'name': 'Polski'}]
# 43187         0.0    75.0           [{'iso_639_1': 'es', 'name': 'Español'}]
#
#          status                                      tagline  \
# 6654   Released                         When Insects Attack!
# 20804  Released                                          NaN
# 6856   Released          Bernardo Bertolucci's Landmark Film
# 25182  Released                                          NaN
# 43187  Released  Kidnapping. Resurrection. Rituals. Secrets.
#
#                      title  video vote_average vote_count
# 6654             Phenomena  False          6.7      146.0
# 20804      Mexican Hayride  False          6.0        5.0
# 6856   Last Tango in Paris  False          7.1      240.0
# 25182        Little Hamlet  False          5.0        1.0
# 43187         White Coffin  False          5.4        9.0
#
# [5 rows x 24 columns]
